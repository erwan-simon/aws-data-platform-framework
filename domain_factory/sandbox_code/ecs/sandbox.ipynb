# %%
import pandas as pd

pd.set_option("display.max_columns", None)
# careful with this one, can freeze your notebook
# pd.set_option("display.max_rows", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from datalake_sdk.native_python_processing_wrapper import job_entrypoint_function
job_entrypoint_function()
